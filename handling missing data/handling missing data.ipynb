# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
path = "C:\\Users\Administrator\\Desktop\\My code\\my note books\\handling missing data\\Data Set\\catalog.csv"


data = pd.read_csv(path)

data.head(4)
# Out:
#    id     date   time continent_code   country_name country_code  \
# 0  34   3/2/07  Night            NaN  United States           US
# 1  42  3/22/07    NaN            NaN  United States           US
# 2  56   4/6/07    NaN            NaN  United States           US
# 3  59  4/14/07    NaN            NaN         Canada           CA
#
#   state/province  population         city/town  distance  ...  \
# 0       Virginia       16000       Cherry Hill   3.40765  ...
# 1           Ohio       17288  New Philadelphia   3.33522  ...
# 2   Pennsylvania       15930       Wilkinsburg   2.91977  ...
# 3         Quebec       42786       Châteauguay   2.98682  ...
#
#                                  geolocation  hazard_type      landslide_type  \
# 0  (38.600900000000003, -77.268199999999993)    Landslide           Landslide
# 1  (40.517499999999998, -81.430499999999995)    Landslide           Landslide
# 2             (40.4377, -79.915999999999997)    Landslide           Landslide
# ...

# %%
missing_value = data.isnull().sum()
missing_value
# Out:
# id                         0
# date                       3
# time                    1064
# continent_code          1529
# country_name               0
# country_code               0
# state/province             1
# population                 0
# city/town                  4
# distance                   1
# location_description    1142
# latitude                   1
# longitude                  1
# geolocation                1
# hazard_type                0
# landslide_type             1
# landslide_size             1
# trigger                    2
# storm_name              1561
# injuries                1178
# fatalities               247
# source_name              821
# source_link              100
# dtype: int64

# %%
total_value = np.product(data.shape)


total_missing = missing_value.sum()


print(f"total value : {total_value} , total missing value : {total_missing}")


print(f"percent of total value : {(total_missing / total_value) * 100}")
# Out:
# total value : 38939 , total missing value : 7658
# percent of total value : 19.66665810626878

# %%
#remove all the row is null

data_not_null_rows = data.dropna()

data_not_null_rows
# Out:
# Empty DataFrame
# Columns: [id, date, time, continent_code, country_name, country_code, state/province, population, city/town, distance, location_description, latitude, longitude, geolocation, hazard_type, landslide_type, landslide_size, trigger, storm_name, injuries, fatalities, source_name, source_link]
# Index: []
#
# [0 rows x 23 columns]

# %%
data_not_null_columns = data.dropna(axis = 1)

data_not_null_columns
# Out:
#         id   country_name country_code  population hazard_type
# 0       34  United States           US       16000   Landslide
# 1       42  United States           US       17288   Landslide
# 2       56  United States           US       15930   Landslide
# 3       59         Canada           CA       42786   Landslide
# 4       61  United States           US        6903   Landslide
# ...    ...            ...          ...         ...         ...
# 1688  7535  United States           US        1646   Landslide
# 1689  7537  United States           US       51400   Landslide
# 1690  7539  United States           US        2406   Landslide
# 1691  7540  United States           US        1048   Landslide
# 1692  7541  United States           US        2066   Landslide
#
# [1693 rows x 5 columns]

# %%
print(f"Columns in original dataset:    number of rows  : {data.shape[0]} and number od columns : {data.shape[1]}")
print(f"Columns with na's dropped:  number of rows : {data_not_null_columns.shape[0]} and number od columns {data_not_null_columns.shape[1]}")
print(f"rows  with na's dropped:  number of rows : {data_not_null_rows.shape[0]} and number od columns : {data_not_null_rows.shape[1]}")
# Out:
# Columns in original dataset:    number of rows  : 1693 and number od columns : 23
# Columns with na's dropped:  number of rows : 1693 and number od columns 5
# rows  with na's dropped:  number of rows : 0 and number od columns : 23

# %%
#filining missing value atoumatcly 

back_up = data

#replave missing value to 0
back_up.fillna(0)

back_up.head(10)
# Out:
#     id     date   time continent_code   country_name country_code  \
# 0   34   3/2/07  Night            NaN  United States           US
# 1   42  3/22/07    NaN            NaN  United States           US
# 2   56   4/6/07    NaN            NaN  United States           US
# 3   59  4/14/07    NaN            NaN         Canada           CA
# 4   61  4/15/07    NaN            NaN  United States           US
# 5   64  4/20/07    NaN            NaN  United States           US
# 6   67  4/24/07    NaN            NaN  United States           US
# 7   77  5/21/07    NaN             SA       Colombia           CO
# 8  105  6/27/07    NaN             SA        Ecuador           EC
# 9  106  6/27/07    NaN             SA        Ecuador           EC
#
#      state/province  population         city/town  distance  ...  \
# 0          Virginia       16000       Cherry Hill   3.40765  ...
# 1              Ohio       17288  New Philadelphia   3.33522  ...
# ...

# %%
count_zero = back_up['storm_name'].value_counts()

count_zero.head()
# Out:
# Tropical Storm Tomas       14
# Hurricane Tomas            13
# Tropical Cyclone Agatha    12
# Manuel                      5
# Ingrid                      5
# Name: storm_name, dtype: int64

# %%
# replace all NA's the value that comes directly after it in the same column, 
# then replace all the remaining na's with 0
data = data.fillna(method = 'bfill', axis = 0).fillna(0)

data
# Out:
#         id     date   time continent_code   country_name country_code  \
# 0       34   3/2/07  Night             SA  United States           US
# 1       42  3/22/07  Night             SA  United States           US
# 2       56   4/6/07  Night             SA  United States           US
# 3       59  4/14/07  Night             SA         Canada           CA
# 4       61  4/15/07  Night             SA  United States           US
# ...    ...      ...    ...            ...            ...          ...
# 1688  7535  12/7/15   0:00              0  United States           US
# 1689  7537  2/22/16   0:00              0  United States           US
# 1690  7539  2/23/16  21:06              0  United States           US
# 1691  7540  2/26/16  21:06              0  United States           US
# 1692  7541   3/2/16   8:00              0  United States           US
#
#       state/province  population         city/town  distance  ...  \
# ...

# %%
missing_value = data.isnull().sum()

missing_value
# Out:
# id                      0
# date                    0
# time                    0
# continent_code          0
# country_name            0
# country_code            0
# state/province          0
# population              0
# city/town               0
# distance                0
# location_description    0
# latitude                0
# longitude               0
# geolocation             0
# hazard_type             0
# landslide_type          0
# landslide_size          0
# trigger                 0
# storm_name              0
# injuries                0
# fatalities              0
# source_name             0
# source_link             0
# dtype: int64
