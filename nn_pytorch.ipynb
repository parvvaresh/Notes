# %% [markdown]
# <a href="https://colab.research.google.com/github/parvvaresh/neural-networks-from-Scratch/blob/main/nn_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Perceptron

# %%
pass
